# %% [markdown]
# <a href="https://colab.research.google.com/github/seongjun47/khu-mock-sugang-my/blob/main/try_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📝 문제 1. 변수와 사칙연산
# 변수 `apple`에 숫자 5를, 변수 `banana`에 숫자 3을 할당하세요.
# 그리고 두 과일의 합을 구하여 `total` 변수에 저장하세요.

# %%
# 아래 None을 지우고 알맞은 숫자나 코드를 적어주세요!

apple = None
banana = None
total = None

print(f"총 과일의 개수는 {total}개 입니다.")

# %%
# 🚨 --- 채점 코드 (수정하지 말고 실행만 하세요!) --- 🚨
try:
    assert apple == 5, "apple의 값이 틀렸습니다."
    assert banana == 3, "banana의 값이 틀렸습니다."
    assert total == 8, "total의 값이 틀렸습니다. (apple과 banana를 더해보세요)"
    print("✅ 정답입니다! 다음 문제로 넘어가세요.")
except AssertionError as e:
    print(f"❌ 오답입니다: {e}")
except NameError:
    print("⚠️ 변수 이름이 잘못되었거나, 위쪽 문제 풀이 셀을 먼저 실행하지 않았습니다.")
